# %%
import pandas as pd
df=pd.read_csv('dataset/Iris.csv')
df.drop(['Id'],axis=1,inplace=True)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Species']=le.fit_transform(df['Species'])
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB
Gnb=GaussianNB()
Gnb.fit(x_train,y_train)
y_predict=Gnb.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_predict))
# Out:
# 1.0

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\ahaly\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_optional_dependencies.py:13, in check_matplotlib_support(caller_name)
#      12 try:
# ---> 13     import matplotlib  # noqa
#      14 except ImportError as e:
#
# ModuleNotFoundError: No module named 'matplotlib'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(ConfusionMatrixDisplay.from_predictions(y_test,y_predict))
#
# File c:\Users\ahaly\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_plot\confusion_matrix.py:455, in ConfusionMatrixDisplay.from_predictions(cls, y_true, y_pred, labels, sample_weight, normalize, display_labels, include_values, xticks_rotation, values_format, cmap, ax, colorbar, im_kw, text_kw)
#     339 @classmethod
#     340 def from_predictions(
#     341     cls,
#    (...)    356     text_kw=None,
#     357 ):
#     358     """Plot Confusion Matrix given true and predicted labels.
#     359
#     360     Read more in the :ref:`User Guide <confusion_matrix>`.
#    (...)    453     >>> plt.show()
#     454     """
# --> 455     check_matplotlib_support(f"{cls.__name__}.from_predictions")
#     457     if display_labels is None:
#     458         if labels is None:
#
# File c:\Users\ahaly\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_optional_dependencies.py:15, in check_matplotlib_support(caller_name)
#      13     import matplotlib  # noqa
#      14 except ImportError as e:
# ---> 15     raise ImportError(
#      16         "{} requires matplotlib. You can install matplotlib with "
#      17         "`pip install matplotlib`".format(caller_name)
#      18     ) from e
#
# ImportError: ConfusionMatrixDisplay.from_predictions requires matplotlib. You can install matplotlib with `pip install matplotlib`
